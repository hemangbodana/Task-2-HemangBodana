# %% [markdown]
# DecodeLabs Task 2
#
# ---

# %% [markdown]
# ### K-Nearest Neighbors (KNN) Classification Example
#
# This example demonstrates how to use the K-Nearest Neighbors algorithm for a simple classification task using the popular Iris dataset.

# %%
# Import necessary libraries
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
import pandas as pd

# Load the Iris dataset
iris = load_iris()
X = iris.data  # Features
y = iris.target  # Target variable

# Display basic information about the dataset
print("Features (X) shape:", X.shape)
print("Target (y) shape:", y.shape)
print("Target names:", iris.target_names)

# Optionally, convert to DataFrame for better viewing
iris_df = pd.DataFrame(X, columns=iris.feature_names)
iris_df['species'] = y
display(iris_df.head())
# Out:
# Features (X) shape: (150, 4)
# Target (y) shape: (150,)
# Target names: ['setosa' 'versicolor' 'virginica']
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    species
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0

# %% [markdown]
# ### Step 1: Data Splitting
#
# We will split the dataset into training and testing sets. The training set will be used to train the model, and the testing set will be used to evaluate its performance on unseen data.

# %%
# Split the dataset into training and testing sets
# test_size=0.3 means 30% of the data will be used for testing
# random_state ensures reproducibility of the split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

print(f"Training set size: {X_train.shape[0]} samples")
print(f"Testing set size: {X_test.shape[0]} samples")
# Out:
# Training set size: 105 samples
# Testing set size: 45 samples

# %% [markdown]
# ### Step 2: Model Training
#
# We will initialize a KNN classifier and train it using the training data. The `n_neighbors` parameter determines the number of neighbors to consider.

# %%
# Initialize the KNN classifier
# We'll use 3 neighbors for this example
knn = KNeighborsClassifier(n_neighbors=3)

# Train the model using the training data
knn.fit(X_train, y_train)

print("KNN model trained successfully!")
# Out:
# KNN model trained successfully!

# %% [markdown]
# ### Step 3: Model Evaluation
#
# After training, we will use the test set to make predictions and evaluate the model's accuracy.

# %%
# Make predictions on the test set
y_pred = knn.predict(X_test)

# Calculate the accuracy of the model
accuracy = accuracy_score(y_test, y_pred)

print(f"Model Accuracy: {accuracy:.2f}")
# Out:
# Model Accuracy: 1.00

# %% [markdown]
# ### Step 4: Confusion Matrix
#
# A confusion matrix is a table that is often used to describe the performance of a classification model on a set of test data for which the true values are known. It allows visualization of the performance of an algorithm. We can use it to identify how many predictions were correct and how many were incorrect, and also to understand the types of errors made.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate the confusion matrix
cm = confusion_matrix(y_test, y_pred)

# Display the confusion matrix using a heatmap for better visualization
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=iris.target_names, yticklabels=iris.target_names)
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.title('Confusion Matrix')
plt.show()
